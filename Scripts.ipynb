# %%
cancerdata <- read.csv("cancer.csv", header=TRUE, stringsAsFactors=FALSE)

# %%
cancerdata
# Out:
#      County                              Population deathRate incidenceRate
# 1    Iosco County, Michigan               25345     193.4     406.2
# 2    Mineral County, Montana               4251     188.8     538.8
# 3    Lake County, Oregon                   7829     139.2     397.2
# 4    Pittsylvania County, Virginia        62194     176.8     399.0
# 5    Hall County, Texas                    3138     223.2     415.8
# 6    Lane County, Kansas                   1670     148.6     371.5
# 7    Northumberland County, Pennsylvania  93246     177.5     471.7
# 8    Knox County, Missouri                 3910     217.7     431.6
# 9    Washington County, Rhode Island     126517     162.2     492.3
# 10   Blount County, Tennessee            127253     172.5     494.2
# 11   Iowa County, Iowa                    16401     163.4     463.3
# 12   Person County, North Carolina        39259     198.1     477.8
# 13   Greene County, Pennsylvania          37519     193.5     501.4
# ...

# %%
#checking the dimension of the data
dim(cancerdata)
# Out:
# [1] 3047   25

# %%
#Checking if the data is continuous
summary(cancerdata)
# Out:
#     County            Population         deathRate     incidenceRate
#  Length:3047        Min.   :     827   Min.   : 59.7   Min.   : 201.3
#  Class :character   1st Qu.:   11684   1st Qu.:161.2   1st Qu.: 413.1
#  Mode  :character   Median :   26643   Median :178.1   Median : 449.5
#                     Mean   :  102637   Mean   :178.7   Mean   : 445.7
#                     3rd Qu.:   68671   3rd Qu.:195.2   3rd Qu.: 482.1
#                     Max.   :10170292   Max.   :362.8   Max.   :1206.9
#    medIncome      povertyPercent    MedianAge      MedianAgeMale
#  Min.   : 22640   Min.   : 3.20   Min.   : 22.30   Min.   :22.40
#  1st Qu.: 38883   1st Qu.:12.15   1st Qu.: 37.70   1st Qu.:36.35
#  Median : 45207   Median :15.90   Median : 41.00   Median :39.60
#  Mean   : 47063   Mean   :16.88   Mean   : 45.27   Mean   :39.57
#  3rd Qu.: 52492   3rd Qu.:20.40   3rd Qu.: 44.00   3rd Qu.:42.50
#  Max.   :125635   Max.   :47.40   Max.   :624.00   Max.   :64.70
# ...

# %%
head(cancerdata)
# Out:
#   County                        Population deathRate incidenceRate medIncome
# 1 Iosco County, Michigan        25345      193.4     406.2         37122
# 2 Mineral County, Montana        4251      188.8     538.8         36449
# 3 Lake County, Oregon            7829      139.2     397.2         40328
# 4 Pittsylvania County, Virginia 62194      176.8     399.0         44207
# 5 Hall County, Texas             3138      223.2     415.8         33324
# 6 Lane County, Kansas            1670      148.6     371.5         53739
#   povertyPercent MedianAge MedianAgeMale MedianAgeFemale AvgHouseholdSize ...
# 1 19.0           624.0     51.6          52.5            2.20             ...
# 2 17.3           619.2     52.3          50.7            2.67             ...
# 3 19.3           579.6     48.2          48.5            2.08             ...
# 4 14.6           546.0     44.2          46.7            2.36             ...
# ...

# %%
str(cancerdata)
# Out:
# 'data.frame':	3047 obs. of  25 variables:
#  $ County                : chr  "Iosco County, Michigan" "Mineral County, Montana" "Lake County, Oregon" "Pittsylvania County, Virginia" ...
#  $ Population            : int  25345 4251 7829 62194 3138 1670 93246 3910 126517 127253 ...
#  $ deathRate             : num  193 189 139 177 223 ...
#  $ incidenceRate         : num  406 539 397 399 416 ...
#  $ medIncome             : int  37122 36449 40328 44207 33324 53739 40429 37581 70705 47175 ...
#  $ povertyPercent        : num  19 17.3 19.3 14.6 24.5 10.9 15.9 19.4 10.4 14.7 ...
#  $ MedianAge             : num  624 619 580 546 536 ...
#  $ MedianAgeMale         : num  51.6 52.3 48.2 44.2 42.8 44.7 41.6 42.4 42 41 ...
#  $ MedianAgeFemale       : num  52.5 50.7 48.5 46.7 45.2 44.4 46.2 45.4 44.5 43.9 ...
#  $ AvgHouseholdSize      : num  2.2 2.67 2.08 2.36 2.71 2.07 2.27 2.34 2.42 2.51 ...
#  $ PctMarriedHouseholds  : num  48.1 46.8 47.6 51.6 51.5 ...
# ...

# %%
cancerdata <- cancerdata[, -1]

# %%
# Check for missing values
is.na(cancerdata)
# Out:
#       Population deathRate incidenceRate medIncome povertyPercent MedianAge
#  [1,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
#  [2,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
#  [3,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
#  [4,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
#  [5,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
#  [6,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
#  [7,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
#  [8,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
#  [9,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
# [10,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
# [11,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
# [12,] FALSE      FALSE     FALSE         FALSE     FALSE          FALSE
# ...

# %%
boxplot(cancerdata$MedianAge, xlab= 'MedianAge', ylab='years')
# Out:
# plot without title

# %%
boxplot(cancerdata$PctOtherRace, xlab= 'PctOtherRace ', ylab='race')
# Out:
# plot without title

# %%
boxplot(cancerdata$medIncome , xlab= 'medIncome', ylab='Salary')
# Out:
# plot without title

# %%
boxplot(cancerdata$PctBachDeg18_24, xlab= 'PctBachDeg18_24', ylab='degreeholder')
# Out:
# plot without title

# %%
boxplot(cancerdata$PctNoHS18_24 , xlab= 'PctNoHS18_24 ', ylab='School')
# Out:
# plot without title

# %% [markdown]
# getting rownames

# %%
histogram <- function(x)
{
title <- paste(deparse(substitute(x), 500), collapse="\n")
sdx <- sd(x)
mx <- mean(x)
hist(x, prob=TRUE,
main=paste("Histogram of ",title),
xlim=c(mx-3*sdx, mx+3*sdx), ylim=c(0, 0.5/sdx))
curve(dnorm(x, mean=mx, sd=sdx), col='red', lwd=3, add=TRUE)
}

# %%
par(mfrow=c(2,2))
histogram(cancerdata$Population)
histogram(cancerdata$deathRate)
histogram(cancerdata$incidenceRate)
histogram(cancerdata$medIncome)
histogram(cancerdata$povertyPercent)
histogram(cancerdata$MedianAge)
histogram(cancerdata$MedianAgeMale)
histogram(cancerdata$MedianAgeFemale)
histogram(cancerdata$AvgHouseholdSize)
histogram(cancerdata$PctMarriedHouseholds)
histogram(cancerdata$PctNoHS18_24)
histogram(cancerdata$PctHS18_24)
histogram(cancerdata$PctBachDeg18_24)
histogram(cancerdata$PctHS25_Over)
histogram(cancerdata$PctBachDeg25_Over)
histogram(cancerdata$PctUnemployed16_Over)
histogram(cancerdata$PctPrivateCoverage)
histogram(cancerdata$PctEmpPrivCoverage)
histogram(cancerdata$PctPublicCoverage)
histogram(cancerdata$PctPublicCoverageAlone)
histogram(cancerdata$PctWhite)
histogram(cancerdata$PctBlack)
histogram(cancerdata$PctAsian)
histogram(cancerdata$PctOtherRace)
# Out:
# Plot with title "Histogram of  cancerdata$medIncome"
# Plot with title "Histogram of  cancerdata$MedianAgeFemale"
# Plot with title "Histogram of  cancerdata$PctHS18_24"
# Plot with title "Histogram of  cancerdata$PctUnemployed16_Over"
# Plot with title "Histogram of  cancerdata$PctPublicCoverageAlone"
# Plot with title "Histogram of  cancerdata$PctOtherRace"

# %%
names(cancerdata)
# Out:
#  [1] "Population"             "deathRate"              "incidenceRate"
#  [4] "medIncome"              "povertyPercent"         "MedianAge"
#  [7] "MedianAgeMale"          "MedianAgeFemale"        "AvgHouseholdSize"
# [10] "PctMarriedHouseholds"   "PctNoHS18_24"           "PctHS18_24"
# [13] "PctBachDeg18_24"        "PctHS25_Over"           "PctBachDeg25_Over"
# [16] "PctUnemployed16_Over"   "PctPrivateCoverage"     "PctEmpPrivCoverage"
# [19] "PctPublicCoverage"      "PctPublicCoverageAlone" "PctWhite"
# [22] "PctBlack"               "PctAsian"               "PctOtherRace"

# %%
model1 <- lm(deathRate ~ Population + incidenceRate + medIncome + povertyPercent + MedianAge + MedianAgeMale + MedianAgeFemale + AvgHouseholdSize + PctMarriedHouseholds + PctNoHS18_24 + PctHS18_24 + PctBachDeg18_24 + PctHS25_Over + PctBachDeg25_Over + PctUnemployed16_Over + PctPrivateCoverage + PctEmpPrivCoverage + PctPublicCoverage + PctPublicCoverageAlone + PctWhite + PctBlack + PctAsian + PctOtherRace, data = cancerdata)

# %%
model12 <- lm(deathrate ~ )
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:27: unexpected ')'
# 1: model12 <- lm(deathrate ~ )
#                               ^
# Traceback:

# %%
summary(model1)

# %% [markdown]
# we could see from the summary the significant variable with the asterik.

# %%
par(mfrow = c(2,2))
plot(model1)

# %%
#Removing Outliers
cancerdata1 <- cancerdata[-c(2410,337,3045,3040,2435),]

# %%
model2 <- lm(deathRate ~ incidenceRate + povertyPercent + AvgHouseholdSize + PctHS18_24 + PctHS25_Over + PctBachDeg25_Over + PctUnemployed16_Over + PctPrivateCoverage + PctWhite + PctEmpPrivCoverage + PctOtherRace,  data = cancerdata)

# %%
summary(model2)

# %%
par(mfrow = c(2,2))
plot(model2)

# %%
#Removing Outliers
cancerdata2 <- cancerdata[-c(3023,1514,2620,1061,655,2636),]

# %%
model3 <- lm(formula = deathRate ~ incidenceRate + povertyPercent + AvgHouseholdSize + 
    PctHS18_24  + PctBachDeg25_Over  + 
    PctPrivateCoverage + PctWhite + PctEmpPrivCoverage + PctOtherRace, 
    data = cancerdata)

# %%
summary(model3)

# %%
par(mfrow = c(2,2))
plot(model3)

# %%
cancerdata2 <- cancerdata[-c(3023,1514,2620,1061,655,2636),]

# %%
model4 <- lm(formula = deathRate ~ incidenceRate + povertyPercent + AvgHouseholdSize + 
    PctHS18_24 + PctWhite +PctBachDeg25_Over+ PctEmpPrivCoverage + PctOtherRace, 
    data = cancerdata)

# %%
summary(model4)

# %%
par(mfrow = c(2,2))
plot(model4)

# %%
model5 <- lm(formula = deathRate ~ incidenceRate + povertyPercent + 
    PctHS18_24 + PctWhite +PctBachDeg25_Over+ PctEmpPrivCoverage + PctOtherRace, 
    data = cancerdata)

# %%
summary(model5)

# %%
par(mfrow = c(2,2))
plot(model5)

# %%
anova(model1, model2, model3, model4, model5)
